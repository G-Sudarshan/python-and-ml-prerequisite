# %%
import pandas as pd

# %%
# list dict

# %%
stu = [['akshay',101,'SE'],
      ['suraj',102,'SE'],
      ['pranali',103,'TE'],
      ['swapnil',101,'BE'],
      ['rahul',102,'BE']]

df = pd.DataFrame(stu,columns=['Name','Roll_No','Class'])


stu1 = {'Name':['akshay','suraj','pranali','swapnil','rahul'],
       'Roll_No':[101,102,103,101,102],
       'Class':['SE','SE','TE','BE','BE']}

df1 = pd.DataFrame(stu1)

# %%
df
# Out:
#       Name  Roll_No Class
# 0   akshay      101    SE
# 1    suraj      102    SE
# 2  pranali      103    TE
# 3  swapnil      101    BE
# 4    rahul      102    BE

# %%
df1
# Out:
#       Name  Roll_No Class
# 0   akshay      101    SE
# 1    suraj      102    SE
# 2  pranali      103    TE
# 3  swapnil      101    BE
# 4    rahul      102    BE

# %%
# axis 0---index of df
# axis 1---column of df
df
# Out:
#       Name  Roll_No Class
# 0   akshay      101    SE
# 1    suraj      102    SE
# 2  pranali      103    TE
# 3  swapnil      101    BE
# 4    rahul      102    BE

# %%
stu1 = {'Name':['akshay','suraj','pranali','swapnil','rahul'],
       'Roll_No':[101,102,103,101,102],
       'Class':['SE','SE','TE','BE','BE']}

df1 = pd.DataFrame(stu1)

# %%
df1
# Out:
#       Name  Roll_No Class
# 0   akshay      101    SE
# 1    suraj      102    SE
# 2  pranali      103    TE
# 3  swapnil      101    BE
# 4    rahul      102    BE

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Name     5 non-null      object
#  1   Roll_No  5 non-null      int64
#  2   Class    5 non-null      object
# dtypes: int64(1), object(2)
# memory usage: 248.0+ bytes

# %%
df.head(2)
# Out:
#      Name  Roll_No Class
# 0  akshay      101    SE
# 1   suraj      102    SE

# %%
df.tail(3)
# Out:
#       Name  Roll_No Class
# 2  pranali      103    TE
# 3  swapnil      101    BE
# 4    rahul      102    BE

# %%
df.describe()
# Out:
#          Roll_No
# count    5.00000
# mean   101.80000
# std      0.83666
# min    101.00000
# 25%    101.00000
# 50%    102.00000
# 75%    102.00000
# max    103.00000

# %%
# Missing value
df.isnull()
# Out:
#     Name  Roll_No  Class
# 0  False    False  False
# 1  False    False  False
# 2  False    False  False
# 3  False    False  False
# 4  False    False  False

# %%
df.isnull().any()
# Out:
# Name       False
# Roll_No    False
# Class      False
# dtype: bool

# %%
df.isnull().sum()
# Out:
# Name       0
# Roll_No    0
# Class      0
# dtype: int64

# %%
import numpy as np

stu1 = {'Name':['akshay',np.nan,'pranali','swapnil','rahul'],
       'Roll_No':[101,102,103,101,np.nan],
       'Class':['SE','SE','TE',np.nan,'BE']}

df1 = pd.DataFrame(stu1)

# %%
df1
# Out:
#       Name  Roll_No Class
# 0   akshay    101.0    SE
# 1      NaN    102.0    SE
# 2  pranali    103.0    TE
# 3  swapnil    101.0   NaN
# 4    rahul      NaN    BE

# %%
df1.isnull().sum()
# Out:
# Name       1
# Roll_No    1
# Class      1
# dtype: int64

# %%
# Imputations
df1.fillna(0)
# Out:
#       Name  Roll_No Class
# 0   akshay    101.0    SE
# 1        0    102.0    SE
# 2  pranali    103.0    TE
# 3  swapnil    101.0     0
# 4    rahul      0.0    BE

# %%
df1
# Out:
#       Name  Roll_No Class
# 0   akshay    101.0    SE
# 1      NaN    102.0    SE
# 2  pranali    103.0    TE
# 3  swapnil    101.0   NaN
# 4    rahul      NaN    BE

# %%
df1['Name'] = df1['Name'].fillna('swami')
df1['Roll_No'] = df1['Roll_No'].fillna(106)
df1['Class'] = df1['Class'].fillna('FE')
df1
# Out:
#       Name  Roll_No Class
# 0   akshay    101.0    SE
# 1    swami    102.0    SE
# 2  pranali    103.0    TE
# 3  swapnil    101.0    FE
# 4    rahul    106.0    BE

# %%
df1
# Out:
#       Name  Roll_No Class
# 0   akshay    101.0    SE
# 1    swami    102.0    SE
# 2  pranali    103.0    TE
# 3  swapnil    101.0    FE
# 4    rahul    106.0    BE

# %%
# df1['marks'] = df1['marks'].fillna(np.mean(df1['marks']))
# df1['rank'] = df1['marks'].fillna(np.mode(df1['rank']))

# %%
df1['Name']
# Out:
# 0     akshay
# 1      swami
# 2    pranali
# 3    swapnil
# 4      rahul
# Name: Name, dtype: object

# %%
df1[['Name','Roll_No']]
# Out:
#       Name  Roll_No
# 0   akshay    101.0
# 1    swami    102.0
# 2  pranali    103.0
# 3  swapnil    101.0
# 4    rahul    106.0

# %%
df1[:]
# Out:
#       Name  Roll_No Class
# 0   akshay    101.0    SE
# 1    swami    102.0    SE
# 2  pranali    103.0    TE
# 3  swapnil    101.0    FE
# 4    rahul    106.0    BE

# %%
# loc----accesss the values based on index/name
# iloc---access value based on index

# %%
df1.loc[2]
# Out:
# Name       pranali
# Roll_No        103
# Class           TE
# Name: 2, dtype: object

# %%
df1.loc[4]
# Out:
# Name       rahul
# Roll_No      106
# Class         BE
# Name: 4, dtype: object

# %%
df1.iloc[:,:1]
# Out:
#       Name
# 0   akshay
# 1    swami
# 2  pranali
# 3  swapnil
# 4    rahul

# %%
df1.iloc[:,1:3]
# Out:
#    Roll_No Class
# 0    101.0    SE
# 1    102.0    SE
# 2    103.0    TE
# 3    101.0    FE
# 4    106.0    BE

# %%
df1.iloc[1:3,1:3]
# Out:
#    Roll_No Class
# 1    102.0    SE
# 2    103.0    TE

# %%
df1
# Out:
#       Name  Roll_No Class
# 0   akshay    101.0    SE
# 1    swami    102.0    SE
# 2  pranali    103.0    TE
# 3  swapnil    101.0    FE
# 4    rahul    106.0    BE

# %%
df1['age'] = [20,22,25,24,22]
df1['city'] = ['pune','mumbai','thane','sangli','satara']

df1
# Out:
#       Name  Roll_No Class  age    city
# 0   akshay    101.0    SE   20    pune
# 1    swami    102.0    SE   22  mumbai
# 2  pranali    103.0    TE   25   thane
# 3  swapnil    101.0    FE   24  sangli
# 4    rahul    106.0    BE   22  satara

# %%
df1.size
# Out:
# 25

# %%
df1.shape
# Out:
# (5, 5)

# %%
df1.loc[5] = ['sakshi',108,'SE',22,'satara']
df1
# Out:
#       Name  Roll_No Class  age    city
# 0   akshay    101.0    SE   20    pune
# 1    swami    102.0    SE   22  mumbai
# 2  pranali    103.0    TE   25   thane
# 3  swapnil    101.0    FE   24  sangli
# 4    rahul    106.0    BE   22  satara
# 5   sakshi    108.0    SE   22  satara

# %%
df1.drop(['city'],axis=1,inplace=True)

# %%
df1
# Out:
#       Name  Roll_No Class  age
# 0   akshay    101.0    SE   20
# 1    swami    102.0    SE   22
# 2  pranali    103.0    TE   25
# 3  swapnil    101.0    FE   24
# 4    rahul    106.0    BE   22
# 5   sakshi    108.0    SE   22

# %%
data = {
    'A':['A1', 'A2', 'A3', 'A4', 'A5'], 
    'B':['B1', 'B2', 'B3', 'B4', 'B5'], 
    'C':['C1', 'C2', 'C3', 'C4', 'C5'], 
    'D':['D1', 'D2', 'D3', 'D4', 'D5'], 
    'E':['E1', 'E2', 'E3', 'E4', 'E5'] }
  
df3 = pd.DataFrame(data)

# %%
df3
# Out:
#     A   B   C   D   E
# 0  A1  B1  C1  D1  E1
# 1  A2  B2  C2  D2  E2
# 2  A3  B3  C3  D3  E3
# 3  A4  B4  C4  D4  E4
# 4  A5  B5  C5  D5  E5

# %%
df3.drop(['D','E'],axis=1)
# Out:
#     A   B   C
# 0  A1  B1  C1
# 1  A2  B2  C2
# 2  A3  B3  C3
# 3  A4  B4  C4
# 4  A5  B5  C5

# %%
df3.drop(df3.iloc[:,3:6],axis=1)
# Out:
#     A   B   C
# 0  A1  B1  C1
# 1  A2  B2  C2
# 2  A3  B3  C3
# 3  A4  B4  C4
# 4  A5  B5  C5

# %%
df3.index
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %%
df1
# Out:
#       Name  Roll_No Class  age
# 0   akshay    101.0    SE   20
# 1    swami    102.0    SE   22
# 2  pranali    103.0    TE   25
# 3  swapnil    101.0    FE   24
# 4    rahul    106.0    BE   22
# 5   sakshi    108.0    SE   22

# %%
df1.sort_values(by='age',ascending=False)
# Out:
#       Name  Roll_No Class  age
# 2  pranali    103.0    TE   25
# 3  swapnil    101.0    FE   24
# 1    swami    102.0    SE   22
# 4    rahul    106.0    BE   22
# 5   sakshi    108.0    SE   22
# 0   akshay    101.0    SE   20

# %%
df1.sort_values(by=['age','Class']).head(3)
# Out:
#      Name  Roll_No Class  age
# 0  akshay    101.0    SE   20
# 4   rahul    106.0    BE   22
# 1   swami    102.0    SE   22

# %%
df1[df1['age'] > 22]
# Out:
#       Name  Roll_No Class  age
# 2  pranali    103.0    TE   25
# 3  swapnil    101.0    FE   24

# %%
df1[df1['age'] < 25]
# Out:
#       Name  Roll_No Class  age
# 0   akshay    101.0    SE   20
# 1    swami    102.0    SE   22
# 3  swapnil    101.0    FE   24
# 4    rahul    106.0    BE   22
# 5   sakshi    108.0    SE   22

# %%
df1[(df1['age'] < 25) & (df1['Class']=='SE')]
# Out:
#      Name  Roll_No Class  age
# 0  akshay    101.0    SE   20
# 1   swami    102.0    SE   22
# 5  sakshi    108.0    SE   22

# %%
df1[(df1['age'] < 25) | (df1['Class']=='SE')]
# Out:
#       Name  Roll_No Class  age
# 0   akshay    101.0    SE   20
# 1    swami    102.0    SE   22
# 3  swapnil    101.0    FE   24
# 4    rahul    106.0    BE   22
# 5   sakshi    108.0    SE   22

# %%
a = ['SE','FE']
df1[df1['Class'].isin(a)]
# Out:
#       Name  Roll_No Class  age
# 0   akshay    101.0    SE   20
# 1    swami    102.0    SE   22
# 3  swapnil    101.0    FE   24
# 5   sakshi    108.0    SE   22

# %%
# str accessor

df1[df1['Name'].str.startswith('s')]
# Out:
#       Name  Roll_No Class  age
# 1    swami    102.0    SE   22
# 3  swapnil    101.0    FE   24
# 5   sakshi    108.0    SE   22

# %%
df1[df1['Name'].str.endswith('y')]
# Out:
#      Name  Roll_No Class  age
# 0  akshay    101.0    SE   20

# %%
df1[df1['Name'].str.contains('a')]
# Out:
#       Name  Roll_No Class  age
# 0   akshay    101.0    SE   20
# 1    swami    102.0    SE   22
# 2  pranali    103.0    TE   25
# 3  swapnil    101.0    FE   24
# 4    rahul    106.0    BE   22
# 5   sakshi    108.0    SE   22

# %%
df1.nlargest(3,'age')
# Out:
#       Name  Roll_No Class  age
# 2  pranali    103.0    TE   25
# 3  swapnil    101.0    FE   24
# 1    swami    102.0    SE   22

# %%
df1.nsmallest(3,'age')
# Out:
#      Name  Roll_No Class  age
# 0  akshay    101.0    SE   20
# 1   swami    102.0    SE   22
# 4   rahul    106.0    BE   22

# %%
covid = pd.read_csv('D:/Data Scienec & ML/Datasets/Covid-19/covid_19_india.csv')
covid
# Out:
#        Sno      Date     Time State/UnionTerritory ConfirmedIndianNational  \
# 0        1  30/01/20  6:00 PM               Kerala                       1
# 1        2  31/01/20  6:00 PM               Kerala                       1
# 2        3  01/02/20  6:00 PM               Kerala                       2
# 3        4  02/02/20  6:00 PM               Kerala                       3
# 4        5  03/02/20  6:00 PM               Kerala                       3
# ...    ...       ...      ...                  ...                     ...
# 8481  8482  16/11/20  8:00 AM            Telengana                       -
# 8482  8483  16/11/20  8:00 AM              Tripura                       -
# 8483  8484  16/11/20  8:00 AM          Uttarakhand                       -
# 8484  8485  16/11/20  8:00 AM        Uttar Pradesh                       -
# 8485  8486  16/11/20  8:00 AM          West Bengal                       -
#
#      ConfirmedForeignNational   Cured  Deaths  Confirmed
# ...

# %%
covid.columns
# Out:
# Index(['Sno', 'Date', 'Time', 'State/UnionTerritory',
#        'ConfirmedIndianNational', 'ConfirmedForeignNational', 'Cured',
#        'Deaths', 'Confirmed'],
#       dtype='object')
